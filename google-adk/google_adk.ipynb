# %% [markdown]
# # Graph Intelligence: Google ADK + Neo4j MCP
#
# This notebook demonstrates how to build a generative AI agent that can autonomously interact with a Neo4j Graph Database using the Model Context Protocol (MCP). We will cover basic graph queries, custom tool creation, and ultimately equip the agent with persistent long-term graph memory.

# %% [markdown]
# ### 1. Environment Setup & Configuration
# First, we install all the necessary libraries:
#
# **google-adk:** The core framework for building agents.
# **neo4j-mcp-server:** The official MCP package from Neo4j for database connectivity.
# **neo4j-agent-memory:** The specialized memory management package for ADK agents.
# **spaCy:** A fast, local NLP library used by the memory package for entity extraction.

# %%
# %pip install -q google-adk requests neo4j-mcp-server neo4j-agent-memory[google-adk,vertex-ai] spacy pydantic python-dotenv
# !python -m spacy download en_core_web_sm

# %% [markdown]
# Now we import the required packages and suppress some standard warnings to keep the output clean.

# %%
import os
os.environ["PYDANTIC_DISABLE_PLUGINS"] = "1"
import base64
import json
import subprocess
import time
import warnings
import uuid
import requests
from getpass import getpass
import logging

from neo4j import GraphDatabase
from google.genai import types
from google.adk.agents.llm_agent import LlmAgent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.artifacts.in_memory_artifact_service import InMemoryArtifactService
from google.adk.tools.mcp_tool import McpToolset, StreamableHTTPConnectionParams
from google.adk.tools.function_tool import FunctionTool
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/google/adk/features/_feature_decorator.py:72: UserWarning: [EXPERIMENTAL] feature FeatureName.PLUGGABLE_AUTH is enabled.
#   check_feature_enabled()

# %%
#Optional

# 1. Suppress standard Python warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# 2. Suppress Google GenAI internal deprecation warnings
warnings.filterwarnings("ignore", module="google.genai.*")
warnings.filterwarnings("ignore", module="google.adk.*")

# 3. Suppress Neo4j DBMS Server Notifications
neo4j_logger = logging.getLogger("neo4j.notifications")
neo4j_logger.setLevel(logging.ERROR)

# %% [markdown]
# ### 2. Global Configuration
# We need to configure credentials for the LLM, the target database (the graph the agent queries), and the memory database (where the agent stores its conversational context).

# %%
# LLM Configuration
os.environ["GOOGLE_API_KEY"] = getpass("Enter Google API Key: ")
os.environ["GEMINI_MODEL"] = "gemini-2.5-flash"

# %% [markdown]
# **DB configuration**

# %%
# Target Database Configuration (The graph the agent queries)
os.environ["NEO4J_URI"] = "neo4j+s://demo.neo4jlabs.com"
os.environ["NEO4J_DATABASE"] = "companies"

# %% [markdown]
# ### 3. Toolset Configuration & MCP Server Start
# We start the Neo4j MCP server as a background process and configure the ADK to connect to it via HTTP.
#
# *Note: Authentication is handled via a Base64 encoded header in the transport layer, not standard environment variables. Do not set NEO4j Username and password as env variables instead pass them as an encoded value in the header.*

# %%
# Encode credentials for HTTP Header
credentials = base64.b64encode(b"companies:companies").decode()
PORT = "8443"

process = subprocess.Popen([
    "neo4j-mcp-server",
    "--neo4j-uri", os.environ["NEO4J_URI"],
    "--neo4j-transport-mode", "http",
    "--neo4j-http-port", PORT,
    "--neo4j-database", os.environ["NEO4J_DATABASE"],
    ],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

time.sleep(3)

poll = process.poll()
if poll is not None:
    stdout, stderr = process.communicate()
    print(f"Server failed to start (Exit Code: {poll})")
    print(stderr)
else:
    print(f"MCP Server started successfully on port {PORT}")



# Defining the tool with HTTP connection parameters, including the Authorization header
mcp_tools = McpToolset(
    connection_params=StreamableHTTPConnectionParams(
        url=f"http://localhost:{PORT}/mcp",
        headers={"Authorization": f"Basic {credentials}"}
    ),
)
# Out:
# MCP Server started successfully on port 8443

# %% [markdown]
# ### 4. Agent Construction
# We wrap the ADK `LlmAgent` creation in an async function.   The agent uses the system prompt to understand it should favor `get-schema` before attempting complex queries.

# %%
async def create_agent(model, name, prompt, tools_list):
    return LlmAgent(
        model=model,
        name=name,
        instruction=prompt,
        tools=tools_list
    )

system_prompt = """
You are a graph database assistant. Your job is to answer user questions by querying Neo4j.

Always run 'get-schema' first if you are unfamiliar with the graph structure.
Use Cypher queries to retrieve data.
If the data is not found, state that clearly.
"""

mcp_agent = await create_agent(
    model=os.environ["GEMINI_MODEL"],
    name="neo4j_explorer",
    prompt=system_prompt,
    tools_list=[mcp_tools]
)

# %% [markdown]
# ### 5. Execution Engine
# The `Runner` orchestrates the conversation, handling the tool calls (the "back-and-forth" between Gemini and Neo4j) automatically. This initial function is "stateless" it does not remember prior sessions.

# %%
async def ask_graph(agent, query):
    session_service = InMemorySessionService()
    artifacts_service = InMemoryArtifactService()

    session = await session_service.create_session(state={}, app_name="neo4j_app", user_id="user_1")
    content = types.Content(role='user', parts=[types.Part(text=query)])

    runner = Runner(
        app_name="neo4j_app",
        agent=agent,
        artifact_service=artifacts_service,
        session_service=session_service,
    )

    print(f"Processing: {query}")
    try:
        events_async = runner.run_async(
            session_id=session.id,
            user_id=session.user_id,
            new_message=content
        )

        async for event in events_async:
            if hasattr(event, 'content') and event.content:
                for part in event.content.parts:
                    if part.text:
                        print(f"Result: {part.text}")
    except Exception as e:
        print(f"Error: {e}")

# Example Query
await ask_graph(mcp_agent, "How many people are in the database?")
# Out:
# Processing: How many people are in the database?
# ...
# Result: There are 8064 people in the database.

# %% [markdown]
# ### 6. Custom Tools
# Beyond using existing MCP servers, you can implement custom tools and add them directly to the agent. This allows you to create specialized functionality tailored to your specific use cases.
#
# Here, we use `GraphDatabase` to establish a direct connection to our database and build a tool that explicitly queries investment relationships. By assigning a function to an agent's tools list, the framework automatically wraps it as a `FunctionTool`.

# %%
async def get_investments(company: str) -> str:
    """
    Returns the investments by a company by name. 
    Returns list of investment ids, names and types.
    """
    query = """
    MATCH (o:Organization)-[:HAS_INVESTOR]->(i)
    WHERE o.name = $company
    RETURN i.id as id, i.name as name, head(labels(i)) as type
    """
    try:
        driver = GraphDatabase.driver(
            os.environ["NEO4J_URI"], 
            auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"]), 
            database=os.environ["NEO4J_DATABASE"]
        )
        records, _, _ = driver.execute_query(query, company=company)
        results = [record.data() for record in records]
        return json.dumps(results, indent=2)
    except Exception as e:
        return f"Error fetching investments: {str(e)}"

custom_investment_tool = FunctionTool(get_investments)

custom_tools = [mcp_tools, custom_investment_tool]
custom_agent_prompt = "You are a helpful assistant with access to a Neo4j graph database containing company data. Use the available tools to query the database and answer questions."

custom_agent = await create_agent(
    os.environ["GEMINI_MODEL"], 
    "Custom_neo4j_agent", 
    custom_agent_prompt, 
    custom_tools
)

await ask_graph(custom_agent, "Which companies did Google invest in?")
# Out:
# Processing: Which companies did Google invest in?
# Result: Google and its investment arms (such as GV, CapitalG, and Google Assistant Investments) have invested in a wide range of companies. Based on the database, here are some of the companies Google has invested in:
#
# ### **Google (Direct & Subsidiaries)**
# *   **Google:** Ionic Security, Avere Systems, FlexiDAO, Cloudflare, Trifacta.
# *   **Google Assistant Investments:** Wysa, Botsociety.
# *   **Google for Startups:** Infermedica, Papaya Global, GrowthSpace.
# *   **Google Cloud:** CNCF (Cloud Native Computing Foundation).
#
# ### **GV (formerly Google Ventures)**
# GV is the venture capital investment arm of Alphabet Inc. Its investments include:
# *   **Data & AI:** Neo4j, Synthesia, DataFox, Datanyze, Segment, Ahana, SingleStore, Cockroach Labs.
# *   **Security:** Duo Security, Recorded Future, Shape Security, Ionic Security.
# ...

# %% [markdown]
# ### 7. Persistent Agent Memory Integration
#
# Standard LLMs suffer from "context amnesia"—they forget previous interactions once a session ends. To build a true enterprise assistant, the agent needs persistent, long-term memory.
#
# In this section, we integrate [neo4j-agent-memory](https://github.com/neo4j-labs/agent-memory). This package equips our Google ADK agent with a dedicated Neo4j graph to store:
#
#
# **Short-term Memory:** The raw conversational history (messages and session data).
# **Long-term Semantic Memory:** Entities, facts, and user preferences automatically extracted from the conversation using `spaCy` and stored as a knowledge graph.

# %% [markdown]
# For using agent-memory we need memory database (where the agent stores its conversational context), alongside Google Cloud credentials for embedding configuration.
#
# Create a `.env` file in the root directory of this notebook with the following configuration:
# ```bash
# # Google Cloud Configuration
# GCP_PROJECT_ID=your-gcp-project-id
# GCP_LOCATION=us-central1
#
# # Memory Database (Where the agent stores session context)
# MEMORY_NEO4J_URI=neo4j+s://your-memory-instance.databases.neo4j.io
# MEMORY_NEO4J_USERNAME=neo4j
# MEMORY_NEO4J_PASSWORD=your-password
# MEMORY_NEO4J_DATABASE=neo4j
# ```

# %% [markdown]
# Note:  Ensure you have authenticated locally via gcloud auth application-default login to use Vertex AI Embedder.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# First, we initialize the memory client globally to manage database connections efficiently.

# %% [markdown]
# #### Advanced Entity Extraction (Optional)
#
# In this notebook, we explicitly configured `MemorySettings` to use LLM (`extractor_type=ExtractorType.LLM`). You can also use spacy for a fast, local-only extraction.
#
# However, `neo4j-agent-memory` is designed with a powerful **Multi-Stage Extraction Pipeline** that cascades from statistical models to zero-shot models, and finally to LLMs (`spaCy` → `GLiNER` → `LLM`). This allows the agent to extract highly complex, domain-specific entities that standard NLP tools might miss.
#
# Refer this for more configuration options - [Extraction Pipeline](https://neo4j.com/labs/agent-memory/#_entity_extraction_pipeline)
#
# We are using gemini flash model for llm extraction we can also use other models with litellm integration. Refer [here](https://github.com/neo4j-labs/agent-memory/blob/main/docs/modules/ROOT/pages/how-to/bring-your-own-model.adoc)

# %%
import os
from neo4j_agent_memory import MemoryClient, MemorySettings
from neo4j_agent_memory.config.settings import (
    Neo4jConfig,
    ExtractionConfig,
    ExtractorType
)

print("Initializing MemorySettings with Vertex AI...")

os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "true"
os.environ["GOOGLE_CLOUD_PROJECT"] = os.environ.get("GCP_PROJECT_ID", "")
os.environ["GOOGLE_CLOUD_LOCATION"] = os.environ.get("GCP_LOCATION", "")

memory_settings = MemorySettings(
    neo4j=Neo4jConfig(
        uri=os.environ.get("MEMORY_NEO4J_URI"),
        username=os.environ.get("MEMORY_NEO4J_USERNAME"),
        password=os.environ.get("MEMORY_NEO4J_PASSWORD"),
        database=os.environ.get("MEMORY_NEO4J_DATABASE")
    ),
    embedding="vertex_ai/text-embedding-004",
    llm="vertex_ai/gemini-2.5-flash", 
    extraction=ExtractionConfig(
        extractor_type=ExtractorType.LLM
    ),
)

global_memory_client = MemoryClient(memory_settings)
await global_memory_client.connect()

print("SUCCESS: Global Memory Client connected and armed with Gemini extraction!")
# Out:
# Initializing MemorySettings with Vertex AI string shorthands...
# SUCCESS: Global Memory Client connected and armed with Gemini extraction!

# %% [markdown]
# ### 8. Native Execution with `neo4j-agent-memory`
# This function orchestrates the ADK flow. It equips the LLM with a custom `recall_memories` tool to perform vector searches against the graph, and uses a dictionary fallback payload to seamlessly save the conversation history back to Neo4j.

# %% [markdown]
# Next, we define a helper function to visually test and retrieve the memories stored in our graph.

# %%
from neo4j_agent_memory.integrations.google_adk import Neo4jMemoryService

async def run_memory_agent(query: str, session_id: str):
    print(f"\n--- Starting Agent Execution for Session: {session_id} ---")
    print(f"USER: {query}")

    session_service = InMemorySessionService()
    artifacts_service = InMemoryArtifactService()

    neo4j_memory_service = Neo4jMemoryService(
        memory_client=global_memory_client,
        user_id="user_001",
        include_entities=True,
        include_preferences=True
    )

    session = await session_service.create_session(
        session_id=session_id, state={}, app_name="memory_assistant", user_id="user_001"
    )

    async def recall_memories(search_query: str) -> str:
        """Search past memories, preferences, and conversations for the user."""
        print(f"   [Tool Executing] Searching graph vectors for: '{search_query}'...")
        response = await neo4j_memory_service.search_memory(search_query, limit=5, threshold=0.3)

        if response and hasattr(response, 'memories') and response.memories:
            results = []
            for memory in response.memories:
                try:
                    if hasattr(memory, 'content') and hasattr(memory.content, 'parts'):
                        text = memory.content.parts[0].text
                    elif isinstance(memory, dict):
                        text = memory["content"]["parts"][0]["text"]
                    elif hasattr(memory, 'content') and isinstance(memory.content, str):
                        text = memory.content
                    else:
                        continue

                    results.append(f"- {text}")
                except Exception as e:
                    print(f"   [Tool Parsing Error] {e}")
                    continue

            if results:
                final_text = "\n".join(results)
                print(f"   [Tool Success] Feeding these exact memories to the LLM:\n{final_text}")
                return final_text

        print("   [Tool Execution] No matching memory found.")
        return "No memory found."

    agent = LlmAgent(
        model=os.environ.get("GEMINI_MODEL", "gemini-2.5-flash"),
        name="assistant",
        instruction=(
            "You are a context-aware AI assistant. "
            "Your memory architecture is passive: every conversation is automatically saved in the background. "
            "When a user asks you to remember or save something, simply acknowledge their request in plain text. "
            "When a user asks you to retrieve, recall, or remind them of past information, you MUST use the 'recall_memories' tool."
        ),
        tools=[recall_memories] 
    )

    runner = Runner(
        app_name="memory_assistant",
        agent=agent,
        artifact_service=artifacts_service,
        session_service=session_service,
        memory_service=neo4j_memory_service
    )

    content = types.Content(role='user', parts=[types.Part(text=query)])

    try:
        events_async = runner.run_async(session_id=session.id, user_id=session.user_id, new_message=content)

        total_response = ""
        async for event in events_async:
            if hasattr(event, 'content') and event.content:
                for part in event.content.parts:
                    if getattr(part, 'text', None):
                        total_response += part.text

        print("\n" + "="*60)
        print(f"ASSISTANT: {total_response}")
        print("="*60 + "\n")

        compatible_session_dict = {
            "id": session.id,
            "messages": [
                {"role": "user", "content": query},
                {"role": "assistant", "content": total_response}
            ]
        }

        await neo4j_memory_service.add_session_to_memory(compatible_session_dict)
        print("   [System] Conversation successfully embedded and saved to Neo4j.")

    except Exception as e:
        print(f"Execution failed: {e}")

    print("--- Execution Complete ---\n")

# %% [markdown]
# Execution Test

# %%
# Step 1: Store the Memory
print("STEP 1: Testing Memory Storage")
session_1_id = f"session_store_{uuid.uuid4().hex[:8]}"
await run_memory_agent(
    query="Just a note for my personal context: I am John Doe and I am researching GenAI and Knowledge Graphs.",
    session_id=session_1_id
)

# Step 2: Retrieve the Memory via Vector Search
print("STEP 2: Testing Native Retrieval")
session_2_id = f"session_retrieve_{uuid.uuid4().hex[:8]}"
await run_memory_agent(
    query="Before we look at any new data, can you remind me which area I am researching?",
    session_id=session_2_id
)
# Out:
# STEP 1: Testing Memory Storage
#
# --- Starting Agent Execution for Session: session_store_228b9674 ---
# USER: Just a note for my personal context: I am John Doe and I am researching GenAI and Knowledge Graphs.
#
# ...
# ASSISTANT: Okay, I'll remember that you are John Doe and you are researching GenAI and Knowledge Graphs.
# ...
#
#    [System] Conversation successfully embedded and saved to Neo4j.
# --- Execution Complete ---
#
# STEP 2: Testing Native Retrieval
#
# --- Starting Agent Execution for Session: session_retrieve_2ca9046b ---
# USER: Before we look at any new data, can you remind me which area I am researching?
#    [Tool Executing] Searching graph vectors for: 'which area I am researching'...
#    [Tool Success] Feeding these exact memories to the LLM:
# - Before we look at any new data, can you remind me which area I am researching?
# - You are researching GenAI and Knowledge Graphs.
# ...

# %% [markdown]
# ### 9. Neo4j Agent Memory Service (NAMS) Integration
# If you do not want to manage the underlying memory database, embedding pipelines, and object parsing yourself, you can use the managed **Neo4j Agent Memory Service (NAMS)**.
#
# Documentation: [memory.neo4jlabs.com](https://memory.neo4jlabs.com/docs)
#
# NAMS runs the GraphRAG and vector embedding pipelines on Neo4j's cloud infrastructure in the background. There are two primary ways to interact with NAMS in your agentic workflows:
#
# **1. Native SDK (System-Driven):** Call the Python SDK directly in your application backend to maintain strict control over conversation threads and memory syncing.
#
# **2. Agent-Driven (MCP Tool):** Give the agent the NAMS MCP server to autonomously manage its own memory using standard tool calls.

# %% [markdown]
# Ensure you have set `MEMORY_API_KEY` in env. You can obtain one from NAMS [portal](https://memory.neo4jlabs.com/dashboard/api-keys)

# %% [markdown]
# #### 9.1 Native SDK (System-Driven)
# In the v0.4 architecture, NAMS operates on strictly isolated Conversation Containers.
# Furthermore, you no longer need to write custom graph entities! You simply log the raw chat messages, and NAMS runs a background extraction pipeline to build the knowledge graph automatically.
#
# **Step 1: Authenticate and Connect**

# %%
import os
from getpass import getpass
from pydantic import SecretStr
from neo4j_agent_memory import MemoryClient, MemorySettings, NamsConfig

if "MEMORY_API_KEY" not in os.environ:
    os.environ["MEMORY_API_KEY"] = getpass("Enter NAMS API Key (starts with nams_): ")

print("Initializing MemorySettings for Native NAMS v0.4...")

settings = MemorySettings(
    backend="nams",
    nams=NamsConfig(
        api_key=SecretStr(os.environ["MEMORY_API_KEY"]),
        validate_on_connect=False
    ),
)

global_nams_client = MemoryClient(settings)
await global_nams_client.connect()

print("SUCCESS: Native NAMS Client Connected and Ready!")
# Out:
# Initializing MemorySettings for Native NAMS v0.4...
# SUCCESS: Native NAMS Client Connected and Ready!

# %% [markdown]
# **Step 2: Define the Native Agent Loop**

# %%
import os
import asyncio
from google.genai import types

async def run_native_nams_agent(query: str, target_conversation_id: str = None) -> str:
    """A completely generic agent wrapper executing against native NAMS v0.4 specifications.

    If target_conversation_id is provided, it uses that specific thread bucket.
    If it is None, it seeds a brand-new cloud conversation container.
    """
    # 1. Resolve or initialize our cloud infrastructure bucket
    if not target_conversation_id:
        print("   [NAMS Pipeline] No active thread ID provided. Seeding new conversation...")
        new_conv = await global_nams_client.short_term.create_conversation(session_id="new_generic_seed")
        active_cloud_id = str(new_conv.id)
    else:
        active_cloud_id = target_conversation_id

    print(f"USER: {query}")

    # 2. Define our dynamic retrieval tool
    async def recall_memories(search_query: str) -> str:
        print(f"   [Tool Executing] LLM dynamically searching NAMS space for: '{search_query}'...")
        results_list = []

        try:
            response_msgs = await global_nams_client.short_term.search_messages(
                search_query,
                session_id=active_cloud_id,
                limit=3
            )
            if response_msgs:
                results_list.extend([f"- Chat History: {msg.content}" for msg in response_msgs if getattr(msg, 'content', None)])
        except Exception as e:
            print(f"   [Warning] Message search error: {e}")

        try:
            response_entities = await global_nams_client.long_term.search_entities(
                query=search_query,
                limit=3
            )
            if response_entities:
                for ent in response_entities:
                    ent_name = getattr(ent, 'name', 'Unknown')
                    ent_desc = getattr(ent, 'description', '')
                    results_list.append(f"- Extracted Fact ({ent_name}): {ent_desc}")
        except Exception as e:
            print(f"   [Warning] Entity search error: {e}")

        if results_list:
            final_text = "\n".join(results_list)
            print(f"   [Tool Success] Context fetched from NAMS cloud pipeline.")
            return final_text

        print("   [Tool Execution] No matching contextual links found.")
        return "No memory found."

    # 3. Instantiate standard LlmAgent
    agent = LlmAgent(
        model=os.environ.get("GEMINI_MODEL", "gemini-2.5-flash"),
        name="assistant",
        instruction=(
            "You are a context-aware AI assistant with access to long-term memory. "
            "When a user asks you to retrieve, recall, or remind them of something, "
            "you MUST invoke the 'recall_memories' tool to fetch context."
        ),
        tools=[recall_memories]
    )

    # 4. Standard Framework Execution
    session_service = InMemorySessionService()
    artifacts_service = InMemoryArtifactService()
    session = await session_service.create_session(
        session_id=active_cloud_id, state={}, app_name="memory_assistant", user_id="user_001"
    )

    runner = Runner(
        app_name="memory_assistant",
        agent=agent,
        artifact_service=artifacts_service,
        session_service=session_service
    )

    content = types.Content(role='user', parts=[types.Part(text=query)])
    total_response = ""

    try:
        events_async = runner.run_async(session_id=session.id, user_id=session.user_id, new_message=content)
        async for event in events_async:
            if hasattr(event, 'content') and event.content:
                for part in event.content.parts:
                    if getattr(part, 'text', None):
                        total_response += part.text
    except Exception as e:
        print(f"Execution core loop failure: {e}")
        return None

    print("\n" + "="*60)
    print(f"ASSISTANT: {total_response}")
    print("="*60 + "\n")

    # 5. Append telemetry payload back into NAMS 
    await global_nams_client.short_term.add_message(
        session_id=active_cloud_id,
        role="user",
        content=query
    )
    await global_nams_client.short_term.add_message(
        session_id=active_cloud_id,
        role="assistant",
        content=total_response
    )

    print("   [System] Frames synchronized. NAMS background compilation running.")
    return None

# %% [markdown]
# **Step 3: Execute the test sequence**

# %%
import asyncio

master_conversation = await global_nams_client.short_term.create_conversation(session_id="master_thread_seed")
nams_cloud_uuid = str(master_conversation.id)

# Step 1: Feed a completely generic contextual fact
print("STEP 1: Storing a query...")
await run_native_nams_agent(
    query="I'm testing out this memory stack. Just so you know, my current favorite coding language is Python.",
    target_conversation_id=nams_cloud_uuid
)

# Wait for cloud ingestion pipeline
print("\n[System] Giving NAMS cloud 3 seconds to auto-extract graph nodes...")
await asyncio.sleep(3)

# Step 2: Query the agent with a generic request that forces the LLM to call the tool
print("STEP 2: Querying the agent generically...")
await run_native_nams_agent(
    query="Hey, can you recall what my favorite coding language is based on our history?",
    target_conversation_id=nams_cloud_uuid
)
# Out:
# STEP 1: Storing a query...
# USER: I'm testing out this memory stack. Just so you know, my current favorite coding language is Python.
#
# ...
# ASSISTANT: Understood! I'll make a note that Python is your favorite coding language.
# ...
#
#    [System] Frames synchronized. NAMS background compilation running.
#
# [System] Giving NAMS cloud 3 seconds to auto-extract graph nodes...
# STEP 2: Querying the agent generically...
# USER: Hey, can you recall what my favorite coding language is based on our history?
#    [Tool Executing] LLM dynamically searching NAMS space for: 'favorite coding language'...
#    [Tool Success] Context fetched from NAMS cloud pipeline.
#
# ...
# ASSISTANT: Based on our history, your favorite coding language is Python.
# ...
#
#    [System] Frames synchronized. NAMS background compilation running.

# %% [markdown]
# #### 9.2 Agent-Driven (NAMS as an MCP Tool)
# Instead of wiring up the API manually or writing custom retrieval logic, we can connect directly to the managed NAMS MCP endpoint.
#
# By giving the LLM the proper system instructions, it will autonomously decide when to trigger tools like `memory_add_messages` or `memory_search_entities`.

# %%
import asyncio

# 1. Configure the NAMS MCP Toolset targeting the Cloud Endpoint
nams_mcp_tools = McpToolset(
    connection_params=StreamableHTTPConnectionParams(
        url="https://memory.neo4jlabs.com/mcp",
        headers={"Authorization": f"Bearer {os.environ['MEMORY_API_KEY']}"}
    )
)

# 2. Define the Agent with Explicit Memory Instructions
nams_system_prompt = """
You are an AI assistant equipped with the Neo4j Agent Memory Service (NAMS) via MCP.
You have access to tools to save conversations, extract entities, and recall past reasoning.

Instructions:
If a user tells you a fact about themselves or the world, use your memory tools (like memory_add_entity or memory_add_messages) to store it. 
If a user asks what you remember or references past context, use memory_search_entities or memory_search_messages to retrieve it before answering.
"""

nams_agent = await create_agent(
    model=os.environ.get("GEMINI_MODEL", "gemini-flash-latest"),
    name="nams_mcp_agent",
    prompt=nams_system_prompt,
    tools_list=[nams_mcp_tools] 
)

# 3. Execution Engine (Tracking Tool Calls)
async def interact_with_nams_agent(user_input, session_id="session_1"):
    session_service = InMemorySessionService()
    artifacts_service = InMemoryArtifactService()

    session = await session_service.create_session(
        session_id=session_id, state={}, app_name="nams_app", user_id="user_001"
    )

    content = types.Content(role='user', parts=[types.Part(text=user_input)])

    runner = Runner(
        app_name="nams_app",
        agent=nams_agent,
        artifact_service=artifacts_service,
        session_service=session_service,
    )

    print(f"\n--USER: {user_input}")

    events = runner.run_async(session_id=session.id, user_id="user_001", new_message=content)

    async for event in events:
        if hasattr(event, 'content') and event.content:
            for part in event.content.parts:
                # Catch and print tool calls to see the agent actively using memory!
                if getattr(part, 'function_call', None):
                    print(f"--[Agent Executing MCP Tool: {part.function_call.name}]")
                elif part.text:
                    print(f"--ASSISTANT: {part.text}")

# 4. Example Workflow
print("--- Turn 1: Storing a Fact via MCP ---")
await interact_with_nams_agent("My name is John Doe and I am researching GenAI and Knowledge Graphs.")

print("\n--- Waiting a moment for cloud vector generation ---")
await asyncio.sleep(3)

print("--- Turn 2: Retrieving a Fact via MCP ---")
await interact_with_nams_agent("Can you search your memory and tell me what my (John Doe's) research interests are?")
# Out:
# --- Turn 1: Storing a Fact via MCP ---
#
# --USER: My name is John Doe and I am researching GenAI and Knowledge Graphs.
# --[Agent Executing MCP Tool: memory_create_conversation]
# --[Agent Executing MCP Tool: memory_add_entity]
# --[Agent Executing MCP Tool: memory_add_entity]
# --[Agent Executing MCP Tool: memory_add_entity]
# --[Agent Executing MCP Tool: memory_add_messages]
# --[Agent Executing MCP Tool: memory_record_step]
# --ASSISTANT: Nice to meet you, John Doe! It's great to hear about your research in GenAI and Knowledge Graphs. I've noted your identity and your interest in these fascinating fields. How can I assist you with your research today?
#
# --- Waiting a moment for cloud vector generation ---
# --- Turn 2: Retrieving a Fact via MCP ---
#
# --USER: Can you search your memory and tell me what my (John Doe's) research interests are?
# --[Agent Executing MCP Tool: memory_search_entities]
# ...

# %% [markdown]
# ### Summary and Conclusion
#
# This notebook demonstrates a robust architecture for building context-aware, database-integrated conversational agents using Google's Agent Development Kit (ADK) and Neo4j.
#
# **Key Architectural Takeaways:**
#
#
# **Separation of Concerns via MCP:** By utilizing the Model Context Protocol (MCP), we securely isolated database query operations from the LLM. The agent interacts with the `neo4j-mcp-server` as a standardized tool, preventing arbitrary code execution while maintaining deep graph visibility.
#
# **Flexible Tooling:** We demonstrated how ADK handles heterogeneous tools natively, seamlessly combining standardized MCP tools with custom-built Python logic.
#
# **Native Memory Integration:** We integrated the open-source `neo4j-agent-memory` directly into the ADK `Runner` to create a passive, background-processed memory system.
#
# **Managed Memory (NAMS):** We showcased how to offload infrastructure burdens by utilizing Neo4j's managed memory service, demonstrating both strict backend control (REST API) and autonomous, agent-driven control (NAMS MCP).
