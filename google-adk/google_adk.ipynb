# %% [markdown]
# # Neo4j + Google ADK: Graph-Powered Agents
#
# Build agents that use a Neo4j knowledge graph as their data layer, using the official
# **Neo4j MCP server** and **Google's Agent Development Kit**.
#
# What this notebook covers:
#
# 1. Running the Neo4j MCP server over HTTP with per-request authentication
# 2. Giving an ADK agent graph access through `McpToolset`
# 3. Adding your own Python tools alongside the MCP tools
# 4. Building a deterministic text-to-Cypher pipeline with a `Workflow` graph
# 5. Persistent agent memory, self-hosted and managed
#
# Everything runs against the public Neo4j demo database, so you only need a Gemini API key
# to get through sections 1-6.

# %% [markdown]
# ---
# ## 1. Setup

# %%
# %pip install -q "google-adk>=2.0.0" aiohttp requests neo4j neo4j-mcp-server "neo4j-agent-memory[google-adk,vertex-ai]" spacy python-dotenv
# !python -m spacy download en_core_web_sm -q
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
os.environ["PYDANTIC_DISABLE_PLUGINS"] = "1"

import asyncio
import base64
import json
import logging
import shutil
import socket
import subprocess
import sys
import time
import uuid
import warnings
from getpass import getpass

import requests
from neo4j import GraphDatabase

from google.genai import types
from google.adk import Agent, Event, Workflow
from google.adk.apps import App
from google.adk.plugins import ReflectAndRetryToolPlugin
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools.function_tool import FunctionTool
from google.adk.tools.mcp_tool import McpToolset, StreamableHTTPConnectionParams

# Keep the notebook output readable.
warnings.filterwarnings("ignore")
logging.getLogger("neo4j.notifications").setLevel(logging.ERROR)

print("ready")
# Out:
# ready
# /usr/local/python/3.12.1/lib/python3.12/site-packages/google/adk/features/_feature_decorator.py:72: UserWarning: [EXPERIMENTAL] feature FeatureName.PLUGGABLE_AUTH is enabled.
#   check_feature_enabled()

# %% [markdown]
# ---
# ## 2. Configuration
#
# Two separate sets of credentials:
#
# * **`GOOGLE_API_KEY`** — the Gemini model that powers the agent.
# * **Neo4j username / password** — the graph the agent queries.
#
# The Neo4j credentials stay as plain Python variables. They are sent in an HTTP header on
# every MCP request, and are deliberately never exported to the server process — section 3
# explains why.

# %%
os.environ["GOOGLE_API_KEY"] = getpass("Enter Google API Key: ")

# Pin an explicit model version. Aliases like `gemini-flash-latest` move over time,
# which makes a reference notebook behave differently month to month.
GEMINI_MODEL = "gemini-flash-latest"

# Public Neo4j demo database - no signup required.
NEO4J_URI = "neo4j+s://demo.neo4jlabs.com"
NEO4J_DATABASE = "companies"
NEO4J_USERNAME = "companies"
NEO4J_PASSWORD = "companies"

MCP_HOST = "127.0.0.1"
MCP_PORT = "8443"
MCP_URL = f"http://{MCP_HOST}:{MCP_PORT}/mcp"

print("Model:", GEMINI_MODEL)
# Out:
# Model: gemini-flash-latest

# %% [markdown]
# ---
# ## 3. Start the Neo4j MCP server
#
# The MCP server sits between the agent and the database. The agent never gets a connection
# string or the ability to run arbitrary code — it calls named tools, and the server decides
# what is allowed.
#
# The server runs in one of two transport modes, and the difference matters:
#
# | | STDIO | HTTP |
# | --- | --- | --- |
# | Process model | One per client | One shared server |
# | Credentials | `NEO4J_USERNAME` / `NEO4J_PASSWORD` at startup | Per-request `Authorization` header |
# | Multi-user | No | Yes — each request can carry different credentials |
#
# We use HTTP. **In HTTP mode the server rejects `NEO4J_USERNAME` and `NEO4J_PASSWORD` at
# startup**, so we strip them from its environment and send them per request instead.
#
# Configuration is via environment variables:
#
# | Variable | Effect |
# | --- | --- |
# | `NEO4J_TRANSPORT_MODE` | `stdio` (default) or `http` |
# | `NEO4J_MCP_HTTP_HOST` / `NEO4J_MCP_HTTP_PORT` | Bind address. **Note the `NEO4J_MCP_` prefix** — without it the server falls back to privileged port 80 and fails to bind |
# | `NEO4J_READ_ONLY` | `true` removes `write-cypher` from the tool list entirely |
# | `NEO4J_SCHEMA_SAMPLE_SIZE` | Records sampled by `get-schema` when inferring property types |
# | `NEO4J_TELEMETRY` | Opt out of usage telemetry |
#
# The server offers four tools: `get-schema`, `read-cypher`, `write-cypher`, and
# `list-gds-procedures`.

# %%
MCP_BINARY = shutil.which("neo4j-mcp") or shutil.which("neo4j-mcp-server")
MCP_COMMAND = [MCP_BINARY] if MCP_BINARY else [sys.executable, "-m", "neo4j_mcp_server"]

server_env = os.environ.copy()
server_env.update({
    "NEO4J_URI": NEO4J_URI,
    "NEO4J_DATABASE": NEO4J_DATABASE,
    "NEO4J_TRANSPORT_MODE": "http",
    "NEO4J_MCP_HTTP_HOST": MCP_HOST,
    "NEO4J_MCP_HTTP_PORT": MCP_PORT,
    "NEO4J_READ_ONLY": "true",
    "NEO4J_TELEMETRY": "false",
    "NEO4J_SCHEMA_SAMPLE_SIZE": "100",
})

# HTTP mode is stateless and refuses startup credentials.
server_env.pop("NEO4J_USERNAME", None)
server_env.pop("NEO4J_PASSWORD", None)

process = subprocess.Popen(
    MCP_COMMAND, env=server_env,
    stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,
)

# Wait for the port instead of sleeping a fixed amount.
deadline, listening = time.time() + 20, False
while time.time() < deadline and process.poll() is None:
    with socket.socket() as probe:
        probe.settimeout(0.5)
        if probe.connect_ex((MCP_HOST, int(MCP_PORT))) == 0:
            listening = True
            break
    time.sleep(0.25)

if listening:
    print("MCP server listening on", MCP_URL)
else:
    print("Server failed to start:\n", process.communicate(timeout=5)[1])
# Out:
# MCP server listening on http://127.0.0.1:8443/mcp

# %% [markdown]
# ---
# ## 4. Authenticate
#
# HTTP mode accepts two credential formats in the `Authorization` header:
#
# * **Basic** — base64-encoded `username:password`. Works on every Neo4j edition. Used below.
# * **Bearer** — an OAuth/OIDC token from your identity provider, passed straight through to
#   Neo4j's auth system. For Aura or Enterprise instances behind SSO. Tokens expire in
#   15–60 minutes, so production code needs a refresh path.
#
# If a proxy already uses the `Authorization` header, start the server with
# `NEO4J_HTTP_AUTH_HEADER_NAME=X-Neo4j-Auth` and send credentials under that name instead.
#
# Verify the credentials with a direct JSON-RPC call before involving the LLM. An auth problem
# is much easier to read here than inside an agent transcript.

# %%
token = base64.b64encode(f"{NEO4J_USERNAME}:{NEO4J_PASSWORD}".encode()).decode()
AUTH_HEADERS = {"Authorization": f"Basic {token}"}

# SSO alternative:
# AUTH_HEADERS = {"Authorization": f"Bearer {os.environ['NEO4J_ACCESS_TOKEN']}"}

response = requests.post(
    MCP_URL,
    headers={**AUTH_HEADERS,
             "Content-Type": "application/json",
             "Accept": "application/json, text/event-stream"},
    json={"jsonrpc": "2.0", "method": "tools/list", "id": 1},
    timeout=30,
)
response.raise_for_status()

# Streamable HTTP may answer as JSON or as a server-sent event stream.
body = response.text
if body.startswith("event:") or "\ndata:" in body:
    body = next(l[5:] for l in body.splitlines() if l.startswith("data:"))

for tool in json.loads(body)["result"]["tools"]:
    print(f"  {tool['name']:<22} {tool.get('description', '').splitlines()[0]}")
# Out:
#   get-schema
#   read-cypher            read-cypher can run only read-only Cypher statements. For write operations (CREATE, MERGE, DELETE, SET, etc...), schema/admin commands, or PROFILE queries, use write-cypher instead.

# %% [markdown]
# Only `get-schema` and `read-cypher` are listed. Because we set `NEO4J_READ_ONLY=true`, the
# server never advertises `write-cypher` — the model cannot call a tool it was never shown,
# which is a stronger guarantee than instructing it not to write.

# %% [markdown]
# ---
# ## 5. Connect the graph to an ADK agent
#
# `McpToolset` handles the MCP connection. Two arguments worth setting:
#
# * **`tool_filter`** — an allow-list on the ADK side. It pairs with `NEO4J_READ_ONLY` for
#   defence in depth, and shortens the tool schema sent with every prompt, which improves
#   tool-selection accuracy.
# * **`progress_callback`** — MCP servers stream progress during long calls. Cypher over a
#   large graph is exactly that case.
#
# The agent is wrapped in an `App`, the container that carries plugins, context caching, and
# resumability config. `ReflectAndRetryToolPlugin` feeds tool errors back to the model so it
# can correct itself — for text-to-Cypher this matters, because a wrong label or property name
# produces a database error that is precisely the hint needed to fix the query.

# %%
async def on_progress(progress: float, total: float, message: str):
    pct = f"{(progress / total) * 100:.0f}%" if total else "..."
    print(f"   [progress {pct}] {message}")


mcp_tools = McpToolset(
    connection_params=StreamableHTTPConnectionParams(
        url=MCP_URL, headers=AUTH_HEADERS, timeout=30,
    ),
    tool_filter=["get-schema", "read-cypher"],
    progress_callback=on_progress,
)

graph_agent = Agent(
    name="neo4j_explorer",
    model=GEMINI_MODEL,
    instruction="""You are a Neo4j graph database assistant.

1. Call `get-schema` before writing Cypher against an unfamiliar graph. Never guess at
   labels, relationship types, or property names.
2. Run read-only queries with `read-cypher`, always with a LIMIT clause.
3. If a query errors, read the error, fix the Cypher, and try again.
4. If the data is not in the graph, say so. Do not invent results.
""",
    tools=[mcp_tools],
)

app = App(
    name="neo4j_app",
    root_agent=graph_agent,
    plugins=[ReflectAndRetryToolPlugin(max_retries=3)],
)

print("Agent ready.")
# Out:
# Agent ready.

# %% [markdown]
# ---
# ## 6. Run it
#
# One helper, used for every example in this notebook. It streams events as they arrive so you
# can watch which tools the agent picks and what arguments it passes.
#
# > For a quick one-liner without the event loop, `InMemoryRunner(app=app).run_debug(query)`
# > prints the conversation and returns the raw events. We use the explicit version because
# > section 7 onwards needs to pass extra services to the `Runner`.

# %%
REDACT_KEYS = {"workspace_id", "user_id", "account_id", "api_key", "token", "authorization"}



def _redact(value):
    if isinstance(value, dict):
        return {k: ("<redacted>" if k.lower() in REDACT_KEYS else _redact(v))
                for k, v in value.items()}
    if isinstance(value, list):
        return [_redact(v) for v in value]
    return value



async def ask(app, query, memory_service=None, show_tools=True, arg_chars=110):
    sessions = InMemorySessionService()
    session = await sessions.create_session(state={}, app_name=app.name, user_id="user_1")
    runner = Runner(app=app, session_service=sessions, memory_service=memory_service)

    print(f"USER: {query}")
    answer = ""

    async for event in runner.run_async(
        session_id=session.id,
        user_id=session.user_id,
        new_message=types.Content(role="user", parts=[types.Part(text=query)]),
    ):
        if not getattr(event, "content", None) or not event.content.parts:
            continue
        for part in event.content.parts:
            if part.function_call and show_tools:
                args = json.dumps(_redact(part.function_call.args), default=str)
                if len(args) > arg_chars:
                    args = args[:arg_chars] + "...}"
                print(f"   -> {part.function_call.name}({args})")
            elif part.function_response and show_tools:
                print(f"   <- {part.function_response.name}")
            elif part.text:
                answer += part.text

    print(f"\nAGENT: {answer.strip()}\n")
    return answer.strip()

await ask(app, "How many people are in the database?")
# Out:
# mTLS was requested but AsyncAuthorizedSession channel is not mTLS
# USER: How many people are in the database?
#    -> get-schema({})
#    <- get-schema
#    -> read-cypher({"query": "MATCH (p:Person) RETURN count(p) AS countOfPeople"})
#    <- read-cypher
#
# AGENT: There are **8,064** people (`Person` nodes) in the database.
# 'There are **8,064** people (`Person` nodes) in the database.'

# %% [markdown]
# ---
# ## 7. Add your own tools
#
# MCP gives the agent general-purpose graph access. Custom tools give it curated access: a
# query you have already tuned, exposed under a name the model can reason about. Both kinds
# go in the same `tools` list.
#
# Note that there is no `try/except` in the tool. The framework catches exceptions itself to
# drive retries and telemetry — a broad `except Exception:` here would hide the error from
# `ReflectAndRetryToolPlugin` and turn a recoverable failure into a wrong answer. Let
# exceptions propagate.

# %%
# One driver, reused. Creating a driver per call is a common performance mistake.
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))


def get_investments(company: str) -> str:
    """Return the companies that a given company has invested in.

    Args:
        company: Exact name of the Organization node, for example "Google".

    Returns:
        JSON list of portfolio companies with id, name, and node type.
    """
    records, _, _ = driver.execute_query(
        """
        MATCH (o:Organization)-[:HAS_INVESTOR]->(i)
        WHERE o.name = $company
        RETURN i.id AS id, i.name AS name, head(labels(i)) AS type
        LIMIT 50
        """,
        company=company,
        database_=NEO4J_DATABASE,
    )
    return json.dumps([r.data() for r in records], indent=2)


investor_app = App(
    name="investor_app",
    root_agent=Agent(
        name="investment_agent",
        model=GEMINI_MODEL,
        instruction=(
            "You answer questions about a graph of company data. Use `get_investments` for "
            "questions about a company's investments. Use `get-schema` and `read-cypher` "
            "for everything else."
        ),
        tools=[mcp_tools, FunctionTool(get_investments)],
    ),
    plugins=[ReflectAndRetryToolPlugin(max_retries=3)],
)

await ask(investor_app, "What has Google invested in?")
# Out:
# USER: What has Google invested in?
#    -> get_investments({"company": "Google"})
#    <- get_investments
#
# AGENT: Google has invested in the following companies:
#
# * **Ionic Security**
# * **Avere Systems**
# * **FlexiDAO**
# * **Cloudflare**
# * **Trifacta**
# 'Google has invested in the following companies:\n\n* **Ionic Security**\n* **Avere Systems**\n* **FlexiDAO**\n* **Cloudflare**\n* **Trifacta**'

# %% [markdown]
# ---
# ## 8. Deterministic pipelines with `Workflow`
#
# An agent told to "check the schema, write Cypher, validate it, then run it" will *mostly*
# comply. Every step is a suggestion it can skip.
#
# A `Workflow` makes the pipeline structural. Each step is a **node** — an agent, a plain
# Python function, or a tool — and **edges** define the transitions. The generative step stays
# generative; validation becomes code that cannot be talked out of running.
#
# ```
# START -> write_cypher (LLM) -> validate (code) --VALID--> run_query (code)
#                                                --INVALID-> reject (code)
# ```
#
# Three things make this work well for text-to-Cypher:
#
# * The LLM only writes Cypher. It never touches the database in this graph.
# * Validation runs `EXPLAIN`, so Neo4j parses and plans the query without executing it. Syntax
#   errors, unknown labels, and write clauses are all caught at zero query cost.
# * A function node returning `Event(route=[...])` picks the branch, and the dict in the edge
#   list dispatches on that value.
#
# Nodes pass data by writing to a shared dict here, which keeps the example readable. ADK also
# supports typed data passing between nodes — see the data-handling guide linked at the end.
#
# > Graph workflows do not support live streaming.

# %%
# Fetch the schema once and bake it into the prompt. Schemas change on deploy timescales,
# not per request, so calling get-schema every turn is wasted latency.
labels, _, _ = driver.execute_query(
    "CALL db.labels() YIELD label RETURN collect(label) AS l", database_=NEO4J_DATABASE)
rels, _, _ = driver.execute_query(
    "CALL db.relationshipTypes() YIELD relationshipType RETURN collect(relationshipType) AS r",
    database_=NEO4J_DATABASE)

SCHEMA = (
    f"Node labels: {labels[0]['l']}\n"
    f"Relationship types: {rels[0]['r']}\n"
    "Common properties: name, id, summary, url."
)
print(SCHEMA)
# Out:
# Node labels: ['_Bloom_Scene_', '_Bloom_Perspective_', 'Person', 'Organization', 'IndustryCategory', 'City', 'Country', 'Article', 'Chunk', 'Fewshot']
# Relationship types: ['HAS_SUBSIDIARY', 'HAS_SUPPLIER', 'HAS_BOARD_MEMBER', 'HAS_PARENT', 'HAS_CHILD', 'HAS_CATEGORY', 'HAS_CEO', 'HAS_INVESTOR', 'HAS_COMPETITOR', 'IN_CITY', 'IN_COUNTRY', 'MENTIONS', 'HAS_CHUNK', '_Bloom_HAS_SCENE_']
# Common properties: name, id, summary, url.

# %%
flow = {}

write_cypher = Agent(
    name="write_cypher",
    model=GEMINI_MODEL,
    instruction=f"""Translate the question into ONE read-only Cypher query.

{SCHEMA}

Output only the query. No prose, no markdown fences. Always include a LIMIT.
Never use CREATE, MERGE, DELETE, SET, REMOVE, or DROP.
""",
    output_schema=str,
)


def validate(node_input: str | None = None):
    """Clean the query, block writes, and EXPLAIN it without executing."""
    cypher = (node_input or "").strip().strip("`").removeprefix("cypher").strip()
    flow["cypher"] = cypher
    print(f"   [validate] {cypher[:80]}")

    if any(w in cypher.upper() for w in ("CREATE", "MERGE", "DELETE", "SET ", "REMOVE", "DROP")):
        flow["error"] = "Query contains a write clause."
        return Event(route=["INVALID"])

    try:
        driver.execute_query(f"EXPLAIN {cypher}", database_=NEO4J_DATABASE)
    except Exception as exc:
        # An invalid query is an expected branch of this graph, not a framework failure,
        # so we catch it here and turn it into a route.
        flow["error"] = str(exc).splitlines()[0]
        return Event(route=["INVALID"])

    return Event(route=["VALID"])


def run_query(node_input: str | None = None):
    records, _, _ = driver.execute_query(flow["cypher"], database_=NEO4J_DATABASE)
    rows = [r.data() for r in records]
    return Event(message=json.dumps(rows, default=str, indent=2))


def reject(node_input: str | None = None):
    return Event(message=f"Query rejected: {flow['error']}\nQuery was: {flow['cypher']}")


text2cypher = App(
    name="text2cypher",
    root_agent=Workflow(
        name="text2cypher_workflow",
        edges=[
            ("START", write_cypher, validate),
            (validate, {"VALID": run_query, "INVALID": reject}),
        ],
    ),
)

print("Workflow assembled.")
# Out:
# Workflow assembled.

# %% [markdown]
# Every node parameter is annotated `str | None`. ADK validates node inputs against the
# annotation, and a routing `Event` carries no payload — so a downstream node bound to a bare
# `str` receives `None` and fails validation before your code runs.

# %%
await ask(text2cypher, "Give me names of Data Analytics companies.", show_tools=False)
# Out:
# USER: Give me names of Data Analytics companies.
#    [validate] MATCH (o:Organization)-[:HAS_CATEGORY]->(c:IndustryCategory) WHERE toLower(c.nam
#
# AGENT: "MATCH (o:Organization)-[:HAS_CATEGORY]->(c:IndustryCategory) WHERE toLower(c.name) CONTAINS 'data analytics' RETURN DISTINCT o.name AS company_name LIMIT 100"[
#   {
#     "company_name": "Veritas Technologies"
#   },
#   {
#     "company_name": "Apigee"
#   },
#   {
#     "company_name": "Tableau Software"
#   },
#   {
#     "company_name": "Trifacta"
#   },
#   {
#     "company_name": "Nice Systems"
#   },
#   {
#     "company_name": "FirstRain"
#   },
#   {
#     "company_name": "Databricks"
#   },
#   {
#     "company_name": "Precisely"
#   },
#   {
#     "company_name": "OverOps"
#   },
#   {
#     "company_name": "Automated Insights"
#   },
#   {
#     "company_name": "Celonis"
#   },
#   {
#     "company_name": "Shareablee"
#   },
#   {
#     "company_name": "Turn"
#   },
#   {
#     "company_name": "Snowflake"
#   },
# ...

# %% [markdown]
# ### Node-level retries
#
# `ReflectAndRetryToolPlugin` handles tool errors by asking the model to reconsider. For
# infrastructure flakiness — a remote MCP server, a rate-limited API — nodes take a
# `RetryConfig` with exponential backoff instead. Exceptions listed in `exceptions` are
# retried; anything else fails the node and propagates through the graph.

# %%
from google.adk.workflow import RetryConfig

retry_policy = RetryConfig(max_attempts=3, initial_delay=1.0, backoff_factor=2.0)
print(retry_policy)
# Out:
# max_attempts=3 initial_delay=1.0 max_delay=None backoff_factor=2.0 jitter=None exceptions=None

# %% [markdown]
# ---
# ## 9. A worked example: the auditable investment brief
#
# The text-to-Cypher workflow showed the mechanics. This section puts them to work on a task
# people actually want: **write an investment brief on a company, where every claim carries a
# citation that has been checked.**
#
# Language models invent citations. They will happily attribute a claim to an article that
# does not exist, and the output looks identical to a correct one. A knowledge graph fixes
# this, because articles are nodes with IDs  so "does this citation exist, and does it
# actually mention this company?" is one Cypher query.
#
# ```
# START -> resolve_company (code)
#            |- NOT_FOUND -> report_missing (code)
#            |- FOUND     -> format_evidence (code) -> draft_brief (LLM)
#                                                        |
#                                                   verify_citations (code)
#                                                        |- VERIFIED -> publish (code)
#                                                        |- FLAGGED  -> publish_flagged (code)
# ```
#
# Everything comes from the `companies` demo graph: profile and industry categories,
# leadership, investors, competitors and suppliers by traversal, and recent articles with
# their numeric `sentiment` property.

# %%
# Shared state between nodes, same pattern as the text-to-Cypher workflow.
brief = {}
from typing import Any



def _node_text(node_input) -> str:
    """START hands a types.Content; downstream nodes hand a plain string."""
    if node_input is None:
        return ""
    if isinstance(node_input, str):
        return node_input.strip()
    parts = getattr(getattr(node_input, "content", node_input), "parts", None) or []
    return "".join(p.text for p in parts if getattr(p, "text", None)).strip()

def _resolve(name: str):
    """Fuzzy-match a company name to an Organization node."""
    try:
        records, _, _ = driver.execute_query(
            """
            CALL db.index.fulltext.queryNodes('entity', $q, {limit: 10})
            YIELD node, score
            WHERE node:Organization
            RETURN node.id AS id, node.name AS name
            ORDER BY score DESC LIMIT 1
            """,
            q=name, database_=NEO4J_DATABASE,
        )
    except Exception:
        # Fall back to a plain match if the full-text index is unavailable.
        records, _, _ = driver.execute_query(
            "MATCH (o:Organization) WHERE toLower(o.name) CONTAINS toLower($q) "
            "RETURN o.id AS id, o.name AS name LIMIT 1",
            q=name, database_=NEO4J_DATABASE,
        )
    return records[0].data() if records else None


def resolve_company(node_input: Any = None):
    """Find the company and pull everything the brief needs from the graph."""
    query = _node_text(node_input)
    match = _resolve(query)
    if not match:
        brief["query"] = query
        return Event(route=["NOT_FOUND"])

    company_id, name = match["id"], match["name"]
    print(f"   [resolve] {query!r} -> {name}")

    profile, _, _ = driver.execute_query(
        """
        MATCH (o:Organization {id: $id})
        OPTIONAL MATCH (o)-[:HAS_CATEGORY]->(c:IndustryCategory)
        OPTIONAL MATCH (o)-[:HAS_CEO]->(ceo:Person)
        RETURN o.name AS name, o.summary AS summary,
               collect(DISTINCT c.name)[..5] AS categories,
               collect(DISTINCT ceo.name)[..3] AS ceos
        """,
        id=company_id, database_=NEO4J_DATABASE,
    )

    # Competitors, investors and suppliers are traversals - the kind of fact a
    # language model cannot recall reliably but a graph answers exactly.
    network, _, _ = driver.execute_query(
        """
        MATCH (o:Organization {id: $id})
        OPTIONAL MATCH (o)-[:HAS_COMPETITOR]->(x:Organization)
        OPTIONAL MATCH (o)-[:HAS_INVESTOR]->(i)
        OPTIONAL MATCH (o)-[:HAS_SUPPLIER]->(s:Organization)
        RETURN collect(DISTINCT x.name)[..8] AS competitors,
               collect(DISTINCT i.name)[..8] AS investors,
               collect(DISTINCT s.name)[..8] AS suppliers
        """,
        id=company_id, database_=NEO4J_DATABASE,
    )

    articles, _, _ = driver.execute_query(
        """
        MATCH (a:Article)-[:MENTIONS]->(o:Organization {id: $id})
        RETURN a.id AS article_id, a.title AS title,
               toString(a.date) AS date, a.sentiment AS sentiment
        ORDER BY a.date DESC LIMIT 10
        """,
        id=company_id, database_=NEO4J_DATABASE,
    )

    brief.clear()
    brief.update({
        "company_id": company_id,
        "name": name,
        "profile": profile[0].data() if profile else {},
        "network": network[0].data() if network else {},
        "articles": [a.data() for a in articles],
    })

    scores = [a["sentiment"] for a in brief["articles"] if a["sentiment"] is not None]
    brief["avg_sentiment"] = round(sum(scores) / len(scores), 3) if scores else None

    print(f"   [gather] {len(brief['articles'])} articles, "
          f"avg sentiment {brief['avg_sentiment']}")
    return Event(route=["FOUND"])


def format_evidence(node_input: str | None = None):
    """Hand the gathered evidence to the drafting model as its input."""
    return Event(message=json.dumps(brief, default=str, indent=2))


def report_missing(node_input: str | None = None):
    return Event(message=f"No company matching {brief.get('query')!r} in the graph.")

# %%
draft_brief = Agent(
    name="draft_brief",
    model=GEMINI_MODEL,
    instruction="""You write short investment briefs from graph evidence.

You receive JSON containing a company profile, its network (competitors, investors,
suppliers), and recent articles with sentiment scores.

Return ONLY a JSON object, no markdown fences:

{
  "thesis": "two sentences on the investment case",
  "risks": ["risk one", "risk two"],
  "evidence": [{"claim": "a specific claim", "article_id": "the id it comes from"}]
}

Every entry in `evidence` MUST cite an `article_id` taken from the articles you were
given. Include three to five claims. Do not invent article IDs.
""",
    output_schema=str,
)


def verify_citations(node_input: str | None = None):
    """Check every cited article against the graph. This is the point of the section."""
    raw = (node_input or "").strip()
    if raw.startswith("```"):
        raw = raw.strip("`").removeprefix("json").strip()

    try:
        draft = json.loads(raw)
    except json.JSONDecodeError:
        brief["draft"] = {"thesis": raw, "risks": [], "evidence": []}
        brief["bad_ids"] = []
        return Event(route=["FLAGGED"])

    brief["draft"] = draft
    cited = [e.get("article_id") for e in draft.get("evidence", []) if e.get("article_id")]

    # One query settles every citation: the article must exist AND mention this company.
    records, _, _ = driver.execute_query(
        """
        MATCH (a:Article)-[:MENTIONS]->(o:Organization {id: $id})
        WHERE a.id IN $ids
        RETURN collect(a.id) AS valid
        """,
        id=brief["company_id"], ids=cited, database_=NEO4J_DATABASE,
    )
    valid = set(records[0]["valid"]) if records else set()
    brief["valid_ids"] = valid
    brief["bad_ids"] = [c for c in cited if c not in valid]

    print(f"   [verify] {len(valid)}/{len(cited)} citations check out")
    return Event(route=["FLAGGED" if brief["bad_ids"] else "VERIFIED"])


def _render(flagged: bool) -> str:
    draft, titles = brief["draft"], {a["article_id"]: a["title"] for a in brief["articles"]}
    lines = [f"# Investment brief: {brief['name']}", "", "## Thesis", draft.get("thesis", ""), ""]

    if draft.get("risks"):
        lines += ["## Risks"] + [f"- {r}" for r in draft["risks"]] + [""]

    lines += ["## Evidence"]
    for item in draft.get("evidence", []):
        aid = item.get("article_id")
        mark = "verified" if aid in brief.get("valid_ids", set()) else "UNVERIFIED"
        lines.append(f"- {item.get('claim')}")
        lines.append(f"  [{mark}] {aid} - {titles.get(aid, 'not in graph')}")

    net = brief["network"]
    lines += ["", "## From the graph",
              f"- Competitors: {', '.join(net.get('competitors') or []) or 'none recorded'}",
              f"- Investors: {', '.join(net.get('investors') or []) or 'none recorded'}",
              f"- Article sentiment (last {len(brief['articles'])}): {brief['avg_sentiment']}"]

    if flagged:
        lines += ["", f"WARNING: {len(brief['bad_ids'])} citation(s) could not be verified "
                      f"against the graph: {brief['bad_ids']}"]
    return "\n".join(lines)


def publish(node_input: str | None = None):
    return Event(message=_render(flagged=False))


def publish_flagged(node_input: str | None = None):
    return Event(message=_render(flagged=True))


brief_app = App(
    name="investment_brief",
    root_agent=Workflow(
        name="investment_brief_workflow",
        edges=[
            ("START", resolve_company),
            (resolve_company, {"FOUND": format_evidence, "NOT_FOUND": report_missing}),
            (format_evidence, draft_brief, verify_citations),
            (verify_citations, {"VERIFIED": publish, "FLAGGED": publish_flagged}),
        ],
    ),
)

print("Investment brief workflow assembled.")
# Out:
# Investment brief workflow assembled.

# %%
await ask(brief_app, "Google", show_tools=False)
# Out:
# USER: Google
#    [resolve] 'Google' -> Google
#    [gather] 8 articles, avg sentiment 0.285
#    [verify] 4/4 citations check out
#
# AGENT: {
#   "company_id": "EUFq-3WlpNsq0pvfUYWXOEA",
#   "name": "Google",
#   "profile": {
#     "name": "Google",
#     "summary": "American multinational technology company",
#     "categories": [
#       "Marketing Companies",
#       "Cloud Computing Providers",
#       "Computer Hardware Companies",
#       "Virtual Reality Companies",
#       "Electronic Products Manufacturers"
#     ],
#     "ceos": []
#   },
#   "network": {
#     "competitors": [],
#     "investors": [
#       "Trifacta",
#       "Avere Systems",
#       "Ionic Security",
#       "Cloudflare",
#       "FlexiDAO"
#     ],
#     "suppliers": [
#       "WPP Digital",
#       "VSP Vision Care",
#       "Cloud Blue Technologies",
#       "Clearwire",
#       "signNow",
#       "Bartle Bogle Hegarty (BBH)",
#       "Mvix",
#       "PRS for Music"
#     ]
#   },
#   "articles": [
# ...

# %% [markdown]
# ---
# ## 10. Persistent memory
#
# Every example so far is stateless — a new session each time, no recollection. For an
# assistant that accumulates context, `neo4j-agent-memory` gives the agent its own Neo4j
# graph holding:
#
# * **Short-term memory** — raw conversation history.
# * **Long-term memory** — entities, facts, and preferences extracted into a knowledge graph.
#
# This is a **second** database, separate from the one the agent queries. The `companies`
# graph is domain knowledge; the memory graph is the agent's own state. Keeping them apart
# keeps both understandable.

# %% [markdown]
# Create a `.env` file next to this notebook:
#
# ```bash
# GCP_PROJECT_ID=your-gcp-project-id
# GCP_LOCATION=us-central1
#
# MEMORY_NEO4J_URI=neo4j+s://your-instance.databases.neo4j.io
# MEMORY_NEO4J_USERNAME=neo4j
# MEMORY_NEO4J_PASSWORD=your-password
# MEMORY_NEO4J_DATABASE=neo4j
# ```
#
# Then authenticate for Vertex AI embeddings. **Both commands are required** — without a quota
# project, every embedding call fails with a 403 and memory silently degrades to storing text
# nobody can search:
#
# ```bash
# gcloud auth application-default login
# gcloud auth application-default set-quota-project YOUR_PROJECT_ID
# gcloud services enable aiplatform.googleapis.com --project YOUR_PROJECT_ID
# ```

# %%
from dotenv import load_dotenv

load_dotenv()

GCP_PROJECT = os.environ["GCP_PROJECT_ID"]
GCP_LOCATION = os.environ.get("GCP_LOCATION", "us-central1")

# Belt and braces: google-auth reads this when ADC has no quota project attached,
# which is the cause of "the aiplatform.googleapis.com API requires a quota project".
os.environ["GOOGLE_CLOUD_PROJECT"] = GCP_PROJECT
os.environ["GOOGLE_CLOUD_QUOTA_PROJECT"] = GCP_PROJECT

# %% [markdown]
# Entity extraction is pinned to spaCy — fast, local, no API calls. In production,
# `neo4j-agent-memory` supports a cascading pipeline (spaCy → GLiNER → LLM) that escalates only
# when the cheaper stage finds nothing, catching domain-specific entities that statistical NER
# misses. See the
# [extraction pipeline docs](https://neo4j.com/labs/agent-memory/#_entity_extraction_pipeline).

# %%
from neo4j_agent_memory import MemoryClient, MemorySettings
from neo4j_agent_memory.config.settings import (
    EmbeddingConfig, EmbeddingProvider, ExtractionConfig, ExtractorType, Neo4jConfig,
)
from neo4j_agent_memory.embeddings.vertex_ai import VertexAIEmbedder

memory_client = MemoryClient(MemorySettings(
    neo4j=Neo4jConfig(
        uri=os.environ["MEMORY_NEO4J_URI"],
        username=os.environ["MEMORY_NEO4J_USERNAME"],
        password=os.environ["MEMORY_NEO4J_PASSWORD"],
        database=os.environ.get("MEMORY_NEO4J_DATABASE", "neo4j"),
    ),
    embedding=EmbeddingConfig(
        provider=EmbeddingProvider.VERTEX_AI,
        model="text-embedding-004",
        dimensions=768,                 # must match the model
        project_id=GCP_PROJECT,
        location=GCP_LOCATION,
    ),
    extraction=ExtractionConfig(extractor_type=ExtractorType.SPACY),
))
await memory_client.connect()

embedder = VertexAIEmbedder(
    model="text-embedding-004", project_id=GCP_PROJECT, location=GCP_LOCATION,
)
memory_client.embedder = embedder
memory_client.short_term._embedder = embedder
memory_client.long_term._embedder = embedder

# Fail loudly now rather than silently storing unsearchable text later. The library logs
# embedding errors and carries on, so an untested embedder looks like working memory
# until a recall returns nothing.
probe = embedder.embed("connection test")
print(f"Embeddings OK - {embedder.dimensions} dimensions")
# Out:
# Embeddings OK - 768 dimensions

# %% [markdown]
# ### A memory-backed agent
#
# Storage and retrieval work differently, and the system prompt has to reflect that:
#
# * **Storage is passive.** The conversation is written back after each turn. The agent does
#   not decide to save anything.
# * **Retrieval is active.** The agent must call `recall_memories`, which runs a vector search
#   against the memory graph.
#
# Prompts that blur the two produce agents that announce they are saving memories they never
# saved.

# %%
from neo4j_agent_memory.integrations.google_adk import Neo4jMemoryService

memory_service = Neo4jMemoryService(
    memory_client=memory_client,
    user_id="user_001",
    include_entities=True,
    include_preferences=True,
)


async def recall_memories(search_query: str) -> str:
    """Search past conversations, facts, and preferences for this user.

    Args:
        search_query: What to look for, in natural language.
    """
    print(f"   [recall] {search_query}")
    result = await memory_service.search_memory(search_query, limit=5, threshold=0.3)

    found = []
    for memory in getattr(result, "memories", []) or []:
        content = getattr(memory, "content", None)
        if hasattr(content, "parts") and content.parts:
            found.append(content.parts[0].text)
        elif isinstance(content, str):
            found.append(content)

    return "\n".join(f"- {f}" for f in found) if found else "No relevant memory found."


memory_app = App(
    name="memory_assistant",
    root_agent=Agent(
        name="memory_assistant",
        model=GEMINI_MODEL,
        instruction=(
            "You are an assistant with persistent memory.\n"
            "Saving is automatic - when the user tells you something, just acknowledge it. "
            "Never claim to be saving it manually.\n"
            "Recall is not automatic - when the user asks you to remember, remind, or "
            "reference anything from the past, call `recall_memories` first."
        ),
        tools=[recall_memories],
    ),
)


async def remember(query: str) -> str:
    """Ask the memory agent, then persist the exchange to the memory graph."""
    answer = await ask(memory_app, query, memory_service=memory_service, show_tools=False)
    await memory_service.add_session_to_memory({
        "id": uuid.uuid4().hex,
        "messages": [
            {"role": "user", "content": query},
            {"role": "assistant", "content": answer},
        ],
    })
    return answer

# %%
await remember("I am John Doe and I research GenAI and Knowledge Graphs.")

# Fresh session - nothing carries over in the context window. Recall must come
# from the graph.
await remember("Remind me which area I am researching?")
# Out:
# USER: I am John Doe and I research GenAI and Knowledge Graphs.
#
# AGENT: Nice to meet you, John! GenAI and Knowledge Graphs are a fascinating and very active intersection of research—combining the generative capabilities of LLMs with the structured, reliable factual representation of knowledge graphs.
#
# How can I help you with your research or work today?
#
# USER: Remind me which area I am researching?
#    [recall] research area topic studying
#
# AGENT: You are researching **Generative AI (GenAI)** and **Knowledge Graphs**.
# 'You are researching **Generative AI (GenAI)** and **Knowledge Graphs**.'

# %% [markdown]
# ---
# ## 10. Managed memory with NAMS
#
# The [Neo4j Agent Memory Service](https://memory.neo4jlabs.com/docs) runs the memory database,
# embeddings, and extraction as a hosted service. Two ways to use it, and the choice is
# architectural:
#
# * **REST** — your backend decides what gets stored. Deterministic and auditable, no LLM in
#   the write path.
# * **MCP** — the agent manages its own memory through tools. Flexible, but the model decides
#   what is worth keeping.
#
# ### 10.1 REST
#
# Use this when a form submission or a business rule, rather than a model, should decide what
# is remembered.

# %%
NAMS_URL = "https://memory.neo4jlabs.com/v1"

if "NAMS_API_KEY" not in os.environ:
    # Get a key at https://memory.neo4jlabs.com/dashboard
    os.environ["NAMS_API_KEY"] = getpass("Enter NAMS API Key: ")

if "NAMS_WORKSPACE_ID" not in os.environ:
    # Get a workspace ID at https://memory.neo4jlabs.com/dashboard
    os.environ["NAMS_WORKSPACE_ID"] = getpass("Enter NAMS Workspace ID: ")

NAMS_HEADERS = {
    "Authorization": f"Bearer {os.environ['NAMS_API_KEY']}",
    "Content-Type": "application/json",
    "X-Workspace-Id": os.environ["NAMS_WORKSPACE_ID"],
}

conv_id = requests.post(f"{NAMS_URL}/conversations", headers=NAMS_HEADERS, json={}).json()["id"]

requests.post(
    f"{NAMS_URL}/conversations/{conv_id}/messages",
    headers=NAMS_HEADERS,
    json={"role": "user",
          "content": "The user has a conservative risk tolerance and prefers "
                     "established AI infrastructure companies."},
).raise_for_status()

print(f"Stored in conversation {conv_id}. Waiting for graph extraction...")
time.sleep(3)

context = requests.get(f"{NAMS_URL}/conversations/{conv_id}/context", headers=NAMS_HEADERS)
print(json.dumps(context.json(), indent=2)[:1200])
# Out:
# Stored in conversation 0f83ff68-d38c-4c7d-9d48-348f69bb8dba. Waiting for graph extraction...
# {
#   "extractionStatus": {
#     "pending": 1
#   },
#   "observations": [],
#   "recentMessages": [
#     {
#       "content": "The user has a conservative risk tolerance and prefers established AI infrastructure companies.",
#       "createdAt": "2026-08-05T09:24:10.054Z",
#       "id": "e73a734b-ed28-4e05-943d-bca1c40d2cb0",
#       "role": "user",
#       "tokenCount": 23
#     }
#   ],
#   "reflections": []
# }

# %% [markdown]
# ### 10.2 MCP
#
# NAMS also exposes an MCP endpoint, so it wires up exactly like the Neo4j server from
# section 3 — only the URL and the auth scheme change. The agent ends up with two MCP servers:
# Neo4j for domain knowledge, NAMS for its own memory.

# %%
nams_app = App(
    name="nams_app",
    root_agent=Agent(
        name="nams_agent",
        model=GEMINI_MODEL,
        instruction=(
            "You have Neo4j graph tools for questions about companies, and NAMS memory "
            "tools for anything about the user.\n"
            "When the user states a fact about themselves, store it with the memory tools. "
            "When they ask what you remember, search the memory tools first, then answer "
            "from what you found."
        ),
        tools=[
            mcp_tools,
            McpToolset(
                connection_params=StreamableHTTPConnectionParams(
                    url="https://memory.neo4jlabs.com/mcp",
                    headers={
                        "Authorization": f"Bearer {os.environ['NAMS_API_KEY']}",
                        "X-Workspace-Id": os.environ["NAMS_WORKSPACE_ID"],
                    },
                ),
            ),
        ],
    ),
    plugins=[ReflectAndRetryToolPlugin(max_retries=3)],
)

await ask(nams_app, "My name is John Doe and I research GenAI and Knowledge Graphs.")

await asyncio.sleep(3)

await ask(nams_app, "Search your memory: what are John Doe's research interests?")
# Out:
# mTLS was requested but AsyncAuthorizedSession channel is not mTLS
# USER: My name is John Doe and I research GenAI and Knowledge Graphs.
#    -> memory_add_entity({"entities": [{"type": "person", "description": "User who researches GenAI and Knowledge Graphs", "name": "Joh...})
#    <- memory_add_entity
#    -> workspace_list({})
#    <- workspace_list
#    -> memory_add_entity({"workspace_id": "<redacted>", "entities": [{"type": "person", "description": "User who researches GenAI and K...})
#    <- memory_add_entity
#    -> memory_create_relation({"relations": [{"target_id": "28a8fb95-46f9-453b-a52b-cb27611777f5", "type": "RESEARCHES", "source_id": "b384f...})
#    <- memory_create_relation
#    -> memory_create_conversation({"metadata": {"title": "User Intro"}, "workspace_id": "<redacted>"})
#    <- memory_create_conversation
#    -> memory_add_messages({"messages": [{"role": "user", "content": "My name is John Doe and I research GenAI and Knowledge Graphs."}], ...})
# ...

# %% [markdown]
# ---
# ## 11. Cleanup
#
# Leaving the MCP server running holds port 8443 and makes the next run fail with a confusing
# bind error.

# %%
try:
    process.terminate()
    process.wait(timeout=5)
except Exception:
    process.kill()
finally:
    driver.close()

print("Stopped.")
# Out:
# Stopped.

# %% [markdown]
# ---
# ## Summary
#
# **The graph is behind a protocol boundary.** The agent never holds a connection string or
# runs arbitrary code. `NEO4J_READ_ONLY=true` means `write-cypher` is never advertised, so
# read-only is a structural property rather than a prompt-level request. Adding `tool_filter`
# constrains the surface from the ADK side too.
#
# **Authentication is per request.** HTTP mode is stateless, with Basic or Bearer credentials
# in the header on every call, so one server can serve many users at different permission
# levels. Startup credentials belong to STDIO mode only.
#
# **Use a workflow where determinism matters.** In the text-to-Cypher graph the model writes
# the query and code decides whether it runs. `EXPLAIN` catches malformed and destructive
# queries before execution at no query cost, and rejection is an explicit branch rather than a
# retry loop.
#
# **Let exceptions propagate.** The framework catches them to drive retries, telemetry, and
# human-in-the-loop pauses. Catch narrowly, only where a failure is a genuine branch of your
# logic — as the validation node does.
#
# **Memory is a separate graph.** Whether self-hosted or on NAMS, agent state lives apart from
# the domain knowledge it queries.
#
# ### Next steps
#
# * [Graph routes](https://adk.dev/graphs/routes/) — fan-out, join nodes, advanced dispatch
# * [Data handling in workflows](https://adk.dev/graphs/data-handling/) — typed data between nodes
# * [Human input nodes](https://adk.dev/graphs/human-input/) — pause for approval before a write
# * [Neo4j MCP configuration](https://neo4j.com/docs/mcp/current/configuration/)
# * [Neo4j MCP authentication](https://neo4j.com/docs/mcp/current/authentication/)
